# %% [markdown]
# # Exercise session 6: Gauss-Newton and Newton-Lagrange
# ### Preliminaries and problem set-up
# First, we will set up the Python environment. To this end, we will import the following modules:
# - **numpy**: package for multi-dimensional arrays
# - **matplotlib**: package for plotting results

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# For Latex formatting of the Python print statements, we also load
from IPython.display import display, Latex

# %% [markdown]
# Throughout this exercise session, we make use of the following functions, which
# - perform a line search using the Armijo conditions and backtracking,
# - evaluate the Jacobian of a vector-valued function using finite-differences.

# %%
def line_search(fun, x0, Jdk, dk, sigma, beta):
    """
    Line search using the Armijo conditions and backtracking.

    Input arguments:
    - fun: scalar function
    - x0: current iterate
    - Jdk: inner product of the gradient of fun evaluated at x0, and the vector dk
    - dk: search direction
    - sigma: armijo condition scalar parameter
    - beta: backtracking parameter

    Returns:
    - x: new iterate
    - alpha: step size
    """

    # Make sure sigma and beta are in a reasonable range
    if sigma <= 0 or 1 <= sigma:
        raise ValueError(f'sigma must be in (0, 1), but equals {sigma}')
    if beta <= 0 or 1 <= beta:
        raise ValueError(f'beta must be in (0, 1), but equals {beta}')
    
    max_iter_left = 1000

    # Initialize alpha, evaluate function
    alpha = 1.
    f0 = fun(x0)

    x = x0 + alpha * dk

    while fun(x) > f0 + sigma * alpha * Jdk:
        # Trial step in x
        alpha *= beta
        x = x0 + alpha * dk

        max_iter_left -= 1

        # If the line search takes too many iterations, throw an Exception
        if max_iter_left == 0:
            raise Exception('Line search failed -- Too many iterations.')
    
    return x, alpha

# %%
def finite_difference_jacob(fun, x0):
    """
    Evaluates the Jacobian of fun at x0 using finite differences.

    Input arguments:
    - fun: real- or vector-valued function
    - x0: current iterate

    Returns:
    - f0: fun evaluated at x0
    - J: Jacobian of fun evaluated at x0
    """
    
    # Make sure x0 is a column vector
    assert x0.ndim == 1, "x0 must be an array"
    Nx = len(x0)

    # Make sure fun returns a column vector
    f0 = fun(x0)
    assert f0.ndim == 1, "fun must return an array"
    Nf = len(f0)

    # Initialize empty J
    J = np.zeros((Nf, Nx))

    # Perform the finite difference Jacobian evaluation
    h = 1e-8
    for k in range(Nx):
        x = np.copy(x0)
        x[k] += h
        f = fun(x)
        J[:, k] = (f - f0) / h

    return f0, J

# %% [markdown]
# ### Exercise 1: Gauss-Newton method
# Let us consider the nonlinear least-squares (NLS) problem: $ \renewcommand\R{\mathrm{I\!R}} $
# \begin{equation*}
# 	\min_{x\in\R^n}~ f(x)=\tfrac{1}{2}\|F(x)\|_2^2,
# \end{equation*}
# where $F(x)=(f_1(x),\dots,f_m(x))$ and $f_i:\R^n\rightarrow \R$ are sufficiently smooth.
#
# The gradient of $f$ is given by
# $$
# 	\nabla f(x) = JF{x}^\top F(x),
# $$
# where $JF{x}$ is the Jacobian of $F$ at $x$.
# If we linearize $F$ around $x$ we get
# \begin{align*}
# 	F(x + \Delta x) \approx F(x) + JF{x}\Delta x.
# \end{align*}
# Therefore, we can approximate $\nabla f$ at the point $x+\Delta x$ by
# \begin{equation} \tag{1.1}
# 	\nabla f(x+\Delta x) \approx JF{x}^\top F(x) + JF{x}^\top JF{x} \Delta x.
# \end{equation}
# When at point $x_k$, we can compute $x_{k+1} = x_k + \Delta x$ by setting $(1.1)$ equal to zero and solving for $\Delta x$.
# Indicating $F_k = F(x_k)$ and $J_k = JF{x_k}$, that is
# $$
# 	\Delta x = - (J_k^TJ_k)^{-1}J_k^T F_k.
# $$
# We already know how to do a linesearch, so let's use $\Delta x$ as our search direction $d_k$.
# When you perform the linesearch, be sure you are evaluating the original function and gradient $f(x)$ and $\nabla f(x)$, and not $F(x)$ and $JF{x}$.
#
# The Python function *ffun* evaluates the NLS objective for a given function $F$, denoted by *Ffun*, at a point $x$.

# %%
def ffun(Ffun, x):
    """
    Evaluates the nonlinear least-squares (NLS) objective

    Input arguments:
    - Ffun: nonlinear function
    - x: point to evaluate the NLS objective at

    Returns:
    - objective value
    """
    
    F = Ffun(x)
    return 0.5 * (F.T @ F)

# %% [markdown]
# **Task 1a**: Implement a Gauss-Newton minimizer by completing the function *minimize_gn*. This minimizer takes in the function $F(x)$, represented by the argument *Ffun*, and an initial guess $x_0$.
#
# * **Warning 1**:
#     The provided *line_search* function has a slightly different prototype than last time: it is given $\nabla f_k^T d_k$ instead of $\nabla f_k$ as one of its arguments.
#
# * **Warning 2**:
#     The provided *finite_difference_jacob* always returns the Jacobian and not the gradient, regardless whether the function is real- or vector-valued. Therefore, in order to retrieve the gradient $\nabla f$, you need to transpose the Jacobian.

# %%
def minimize_gn(Ffun, x0, Ffun_jac = None):
    """
    Minimizes a nonlinear least-squares (NLS) objective 
    using a Gauss-Newton method.

    Input arguments:
    - Ffun: nonlinear function
    - x0: Initial iterate

    Returns:
    - x: Final iterate
    - x_iters: Log of the iterates
    - x_grads: Log of the gradient norms
    """

    # Convergence tolerance
    grad_tol = 1e-4
    max_iters = 200

    # Make sure x0 is a column vector
    assert x0.ndim == 1, "x0 must be an array"

    # Make sure Ffun returns a column vector
    f0 = Ffun(x0)
    assert f0.ndim == 1, "Ffun must return an array"

    # Log of the iterations
    x_iters = np.zeros((len(x0), max_iters))
    grad_iters = np.zeros(max_iters)

    x = np.copy(x0)

    for k in range(max_iters):
        # Check for divergence
        if np.max(np.abs(x)) > 1e6:
            raise AssertionError(f'minimize_gn has diverged, np.max(np.abs(x)) = {np.max(np.abs(x))}')
        
        # Evaluate F and its Jacobian J
        if Ffun_jac is not None:
            F = Ffun(x)
            J = Ffun_jac(x)
        else:
            F, J = finite_difference_jacob(Ffun, x)

        norm_grad = np.linalg.norm(J.T @ F, ord = np.inf)

        # Update the iteration log
        x_iters[:, k] = np.copy(x)
        grad_iters[k] = norm_grad

        display(Latex(rf'Iteration {k}: $\|J^\top F\|_\infty$ = {norm_grad}'))
        print(np.linalg.cond(J))

        # Check for convergence
        if norm_grad < grad_tol:
            return x, x_iters[:, 0:k+1], grad_iters[0:k+1]
        
        ###################### FILL THIS PART IN ####################
        
        # Find the search direction
        dk = -np.linalg.solve(J.T @ J, J.T @ F)
        f_grad = J.T @ F
        
        # Line search
        sigma = 0.01
        beta = 0.6
        x, _ = line_search(lambda y : ffun(Ffun, y), x, f_grad.T @ dk, dk, sigma, beta)

        #############################################################
    
    raise(AssertionError(f'minimize_gn has diverged, maximum number of iterations attained.'))

# %% [markdown]
# **Task 1b**: A typical problem solved by Gauss-Newton is nonlinear regression. We will fit monthly average temperatures using a sinusoidal model:
# \begin{equation} \tag{1.2}
#     T(k) = A \sin(\omega k + \phi) + C.
# \end{equation}
# Here $T$ denotes the average temperature for month $k$.
# In particular, given a data set of $\{k_i,T_i\}$ pairs, the Gauss-Newton method minimizes the objective function:
# \begin{equation} \tag{1.3}
#     \min_{A, \omega, \phi, C}~ \tfrac 12\sum_i(T(k(i))-y_i)^2.
# \end{equation}
# Fit these data by completing the code below.
# Try different initial points. What do you observe?
#
# <!-- **A successful minimization should look like:
# TO DO: Keep figure?** -->

# %%
def Ffun(x, k, y):
    """
    Evaluates the NLS objective for the sinusoidal model given by formula (1.2).
    
    Use this formula with
    A = x[0]
    w = x[1]
    phi = x[2]
    C = x[3]

    Input arguments:
    - x: fitting parameters [A, w, phi, C]
    - k: the months data
    - y: the average temperature data

    Returns:
    - F: evaluates the NLS objective (1.2) at x
    """
    A = x[0]
    w = x[1]
    phi = x[2]
    C = x[3]
    
    ###################### FILL THIS PART IN ####################
    F = A * np.sin(w * k + phi) + C - y
    #############################################################
    return F

def Ffun_jac(x, k, y):
    """
    Evaluates the Jacobian of the NLS objective for the sinusoidal model given by formula (1.2).
    
    Use this formula with
    A = x[0]
    w = x[1]
    phi = x[2]
    C = x[3]

    Input arguments:
    - x: fitting parameters [A, w, phi, C]
    - k: the months data
    - y: the average temperature data

    Returns:
    - JF: Jacobian of the NLS objective (1.2) at x
    """
    A = x[0]
    w = x[1]
    phi = x[2]
    C = x[3]

    J = np.zeros((len(y), len(x)))
    ###################### FILL THIS PART IN ####################
    J[:, 0] = np.sin(w * k + phi)
    J[:, 1] = k * A * np.cos(w * k + phi)
    J[:, 2] = A * np.cos(w * k + phi)
    J[:, 3] = np.ones_like(y)
    #############################################################
    return J

# %%
# Fit the given average temperature data to a sinusoidal model using the Gauss-Newton method.

# Play around with different initial points x0.
# x0 = np.ones(4)
x0 = np.array([15, 0.4, 10 , 1])

k = np.array([i for i in range(1, 13)])
y = np.array([56, 60, 69, 77, 84, 90, 94, 94, 88, 79, 68, 58])

# Call Gauss-Newton implementation
x, _, grad_iters = minimize_gn(lambda x : Ffun(x, k, y), x0, Ffun_jac = lambda x : Ffun_jac(x, k, y))

# Create figure handle
fig1 = plt.figure()

# Plot data and fitted model
ax1 = fig1.add_subplot(211)
plt.plot(k, y, 'b.', label='data')
plt.plot(k, x[0] * np.sin(x[1] * k + x[2]) + x[3], 'r', label = 'curve fit')
ax1.set_xlabel('Month')
ax1.set_ylabel('Average temperature')
ax1.set_title('Average temperature per month')
ax1.legend()

# Plot gradient norms
ax2 = fig1.add_subplot(212)
plt.semilogy(grad_iters, '.')
plt.grid(True)
ax2.set_xlabel('Iteration')
ax2.set_ylabel(r'$\|\nabla f(x^k)\|_\infty$')
ax2.set_title('Gradient norm at each iteration')

# Adjust vertical separation between plots and plot results
plt.subplots_adjust(hspace=0.6)
plt.show()
# Out:
# Iteration 0: $\|J^\top F\|_\infty$ = 33092.18803012469
# 86.52469648764753
# Iteration 1: $\|J^\top F\|_\infty$ = 1398.256722552354
# 161.8415695442812
# Iteration 2: $\|J^\top F\|_\infty$ = 11967.559970549908
# 542.6547665057323
# Iteration 3: $\|J^\top F\|_\infty$ = 1854.260196014119
# 454.6838637175467
# Iteration 4: $\|J^\top F\|_\infty$ = 197.23524326895046
# 422.85146333349115
# Iteration 5: $\|J^\top F\|_\infty$ = 28.840511089724835
# 376.9566336625567
# Iteration 6: $\|J^\top F\|_\infty$ = 5.658741737835258
# 382.6660866392829
# Iteration 7: $\|J^\top F\|_\infty$ = 0.8564016458511684
# 381.78480761093624
# Iteration 8: $\|J^\top F\|_\infty$ = 0.13039845763210323
# 381.9171215230374
# Iteration 9: $\|J^\top F\|_\infty$ = 0.020313350670826912
# 381.89624637592
# Iteration 10: $\|J^\top F\|_\infty$ = 0.003077403606167311
# 381.8993682372637
# Iteration 11: $\|J^\top F\|_\infty$ = 0.0004802496035861289
# 381.8988744738739
# Iteration 12: $\|J^\top F\|_\infty$ = 7.265943431064854e-05
# 381.8989481414892

# %% [markdown]
# ### Exercise 2: Newton-Lagrange Method
# Consider the problem:
# \begin{equation} \tag{2.1}
# 	\min_{x\in \R^n}~f(x)
# \quad\text{subject to}\quad
# 	h(x) = 0,
# \end{equation}
# where $f : \R^n \to \R$ and $h : \R^n \to \R^p$.
# We handle the constraints by introducing the Lagrange multipliers $\lambda\in\R^p$ and the Lagrangian function:
# $$
# 	L(x,\lambda) = f(x) + \lambda^{\top}h(x).
# $$
# Our goal is to solve the nonlinear system of equations $\nabla L(x,\lambda)=0$ defining the optimality conditions (KKT), namely
# \begin{align*}
# 	0 = \nabla_xL(x,\lambda) &{}= \nabla f(x) + J h(x)^{\top} \lambda \\
# 	0 = \nabla_\lambda L(x,\lambda) &{}= h(x).
# \end{align*}
# We linearize this system around $(x_k, \lambda_k)$: denoting $f_k\coloneqq f(x_k)$, $h_k\coloneqq h(x_k)$, $x\coloneqq x_k + \Delta x$, $\lambda\coloneqq\lambda_k + \Delta \lambda$ and $L_k\coloneqq L(x_k,\lambda_k)$,
# \begin{align*}
# 	\nabla_xL(x,\lambda)
# {}\approx{} &
# 	\overbrace{
# 		\vphantom{X^{X^X}}\nabla_x L(x_k,\lambda_k)
# 	}^{
# 		\mathclap{\nabla f_k + Jh_k^{\top} \lambda_k}
# 	}
# 	{}+{}
# 	\overbrace{
# 		\nabla_x\left(\nabla_x L(x_k,\lambda_k)\right)^{\top}
# 	}^{\nabla_{xx}^2L_k}
# 	\Delta x
# 	{}+{}
# 	\overbrace{
# 		\nabla_\lambda\left(\nabla_x L(x_k,\lambda_k)\right)^{\top}
# 	}^{Jh_k^{\top}}
# 	\Delta\lambda
# \\
# {}={} &
# 	\nabla f_k + Jh_k^{\top}\lambda_k + \nabla_{xx}^2L_k\Delta x + Jh_k^{\top}(\lambda - \lambda_k)
# \\
# {}={} &
# 	 \nabla f_k + \nabla_{xx}^2L_k\Delta x + Jh_k^{\top} \lambda
# \end{align*}
# and
# \begin{align*}
# 	\nabla_\lambda L(x,\lambda)
# {}\approx{} &
# 	 h_k + Jh_k\Delta x.
# \end{align*}
# We now have the linearized system:
# \begin{equation} \tag{2.2}
# 	\left[
# 		\begin{array}{cc}
# 			\nabla_{xx}^2L_k & Jh_k^{\top} \\
# 			Jh_k & 0 \\
# 		\end{array}
# 	\right]
# 	\left(
# 		\begin{array}{c}
# 			\Delta x \\ \lambda
# 		\end{array}
# 	\right)
# {}={}
# 	\left(
# 		\begin{array}{c}
# 			-\nabla f_k \\ -h_k
# 		\end{array}
# 	\right).
# \end{equation}
# By solving (2.2) we obtain $\Delta x$ and $\lambda$.
# Therefore, we can set $\lambda_{k+1}=\lambda$ and find $x_{k+1}$ with a line search in direction $d_k=\Delta x$ to obtain $x_{k+1} = x_k + \alpha_k\,d_k$.
# The step length $\alpha_k$ can be computed by employing the Armijo condition:
# \begin{equation} \tag{2.3}
# 	\varphi(x_k + \alpha_k d_k) \leq{} \varphi(x_k) + \sigma \alpha_k \varphi'(x_k;d_k)
# \end{equation}
# where $\varphi(x)$ is the *merit function* defined by
# \begin{equation} \tag{2.4}
# 	\varphi(x) \coloneqq f(x) + c \|h(x)\|_1,
# \end{equation}
# where $c>0$ is the *penalty parameter*. $\varphi(x)$ is nonsmooth due to the nonsmoothness of the $\|{}\cdot{}\|_1$ norm; however, the *directional derivative* $\varphi'(x_k;d_k)$ exists and equals
# \begin{equation} \tag{2.5}
# 	\varphi'(x_k;d_k) = \nabla f_k^{\top}d_k - c \|h_k\|_1.
# \end{equation}

# %%
# Implementation of the merit function
def merit_fun(ffun, hfun, c, x):
    """
    Evaluates the merit function (2.4)

    Input arguments:
    - ffun: scalar-valued function
    - hfun: vector-valued function 
    - c: penalty parameter, strictly positive
    - x: the current iterate

    Returns:
    - the merit function (2.4) evaluated at x
    """
    assert c > 0, "The penalty parameter c must be strictly positive."

    f = ffun(x)
    h = hfun(x)
    return f + c * np.linalg.norm(h, ord = 1)

# %% [markdown]
# **Task 2a**: Implement the Newton Lagrange method, using the BFGS method to approximate $\nabla_{xx}^2L_k$, by completing the function *minimize_nl*.
# The BFGS algorithm should follow Section 7.6.1 (page 135) of the Numerical Optimization script (https://p.cygnus.cc.kuleuven.be/bbcswebdav/pid-30052757-dt-content-rid-307696315_2/xid-307696315_2) or the Exercise 3 from Exercise Session 3.
# This minimizer takes in the functions $f(x)$, $h(x)$ and an initial guess $x_0$.
#
# Use the stopping criterion:
# $$
#     \left\|
#     \begin{array}{c}
#         \nabla_x L(x_k, \lambda_k) \\
#         \nabla_{\lambda} L(x_k, \lambda_k)
#     \end{array} \right\|_\infty =  \left\|
#     \begin{array}{c}
#         \nabla f_k + Jh_k^{\top} \lambda_k \\
#         h_k
#     \end{array} \right\|_\infty
# {}<{}
#     10^{-4}.
# $$

# %%
def minimize_nl(ffun, hfun, x0):
    """
    minimizes the problem (2.1) using a Newton-Lagrange method

    Input arguments:
    - ffun: the function f, real-valued
    - hfun: the function h, vector-valued
    - x0: the initial iterate

    Returns:
    - x: Final iterate
    - x_iters: Log of the iterates
    - x_grads: Log of the gradient norms
    """
    
    # Convergence tolerance
    grad_tol = 1e-4
    max_iters = 1000

    # Check that x0 is a column vector
    assert x0.ndim == 1, "x0 must be an array"

    # Make sure ffun returns a scalar
    f0 = ffun(x0)
    assert f0.ndim == 0, "ffun must return a scalar"

    # Make sure that hfun returns a column vector
    h0 = hfun(x0)
    assert h0.ndim == 1, "hfun must return an array"

    # Iteration logs
    x_iters = np.zeros((len(x0), max_iters))
    f_iters = np.zeros(max_iters)

    # Initialization
    x = np.copy(x0)
    lmbd = np.zeros_like(h0)
    B = np.identity(len(x0)) # BFGS matrix

    # Evaluate the initial f and its Jacobian J
    # ffun returns a scalar, finite_difference_jacob expects an array!
    _, J = finite_difference_jacob(lambda z: np.array([ffun(z)]), x)

    # Evaluate the initial h and its Jacobian J_h
    h, J_h = finite_difference_jacob(hfun, x)

    for k in range(max_iters):
        # Check for divergence
        if np.max(np.abs(x)) > 1e6:
            raise AssertionError(f'minimize_nl has diverged, np.max(np.abs(x)) = {np.max(np.abs(x))}')
        
        # Update iteration log
        norm_grad_L = np.linalg.norm(
            np.concatenate([
                np.matrix.flatten(J.T + J_h.T @ lmbd.reshape((-1,1))), 
                h
            ]),
            ord = np.inf
        )
        x_iters[:, k] = np.copy(x)
        f_iters[k] = norm_grad_L
        display(Latex(rf'Iteration: {k}, $\|\nabla L\|_\infty$ = {norm_grad_L}'))

        # Check for convergence
        if norm_grad_L < grad_tol:
            return x, x_iters[:, 0:k+1], f_iters[0:k+1]
        
        x_old = np.copy(x)
        
        ###################### FILL THIS PART IN ####################
        # Find the search direction and lmbd
        M = np.block([[B, J_h.T], [np.matrix.flatten(J_h), np.zeros_like(lmbd)]])
        sol = np.linalg.solve(M, np.concatenate([-np.matrix.flatten(J.T), -h]))

        # Now sol is the vector [Delta_x; lmbd]
        dk = sol[0:len(x)]
        lmbd = sol[len(x) :]

        # Line search
        sigma = 0.01
        beta = 0.6
        c = 100
        x, _ = line_search(lambda y : merit_fun(ffun, hfun, c, y), x, J @ dk - c * np.linalg.norm(h, ord = 1), dk, sigma, beta)

        # Update BFGS Hessian approximation
        J_old = np.copy(J)
        J_h_old = np.copy(J_h)

        # ffun returns a scalar, finite_difference_jacob expects an array!
        _, J = finite_difference_jacob(lambda z: np.array([ffun(z)]), x)
        h, J_h = finite_difference_jacob(hfun, x)

        Lx_old = J_old.T + J_h_old.T * lmbd
        Lx = J.T + J_h.T * lmbd

        s = x - x_old
        y = Lx - Lx_old

        Bs = B @ s
        B = B - np.outer(Bs, Bs / np.dot(s, Bs)) + np.outer(y, y / np.dot(s, y))
        
        # Symmetrize Hessian (only needed for numerical accuracy)
        B = (B + B.T) / 2.

        #############################################################

    raise(AssertionError(f'minimize_nl has diverged, maximum number of iterations attained.'))

# %% [markdown]
# **Task 2b**: Solve the problem:
# $$
#     \min_{x,y}~ \tfrac 12\left( x^2 + \left(\frac y2\right)^2 \right)
# \quad\text{s.t.}\quad
#     y = (x-1)^2 - x + 3
# $$
# by completing the function *ffun* and *hfun*.

# %%
def ffun(xy):
    """
    Evaluates the scalar function f

    Input arguments:
    - xy: the vector [x, y]
    
    Returns: f evaluated at xy (= a scalar)
    """
    x = xy[0]
    y = xy[1]

    ###################### FILL THIS PART IN ####################
    f = .5 * np.square(x) + .5*np.square(y * .5)
    #############################################################
    return f

def hfun(xy):
    """
    Evaluates the vector-valued function h

    Input arguments:
    - xy: the vector [x, y]

    Returns: h evaluated at xy (=an array)
    """
    x = xy[0]
    y = xy[1]
    ###################### FILL THIS PART IN ####################
    h = np.array([np.square(x - 1.) - x + 3. - y])
    #############################################################
    return h

# %%
# Create figure handle, plot objective and constraint
fig2 = plt.figure()
X, Y = np.meshgrid(
    np.linspace(-1., 4., 40),
    np.linspace(-3., 4., 40)
)
obj = np.copy(X)
for i in range(np.shape(X)[0]):
    for j in range(np.shape(X)[1]):
        obj[i, j] = ffun([X[i, j], Y[i, j]])

c = plt.contour(X, Y, obj, 40)
t = np.linspace(-1., 4, 400)
plt.plot(t, 3. + np.square(t - 1.) - t, 'k', label = 'Constraint')
plt.xlim([-1., 4.])
plt.ylim([-3., 4.])

# Call the Newton-Lagrange method
x0 = np.array([3., 1.])
x0 = np.array([2.5, 3.])
_, x, grad_iters = minimize_nl(lambda x : ffun(x), lambda x: hfun(x), x0)

# Plot solution
plt.plot(x[0, :], x[1, :], 'ro-', label="Iterates")
plt.xlabel('x')
plt.ylabel('y')
plt.title('Solution to the constrained optimization problem')
plt.legend()
plt.show()

# Plot the gradient norms
fig3 = plt.figure()
plt.semilogy(grad_iters, '.')
plt.grid(True)
plt.title('Gradient norm at each iteration')
plt.xlabel('iterations')
plt.ylabel(r'$\|\nabla L(x_k, \lambda_k\|_\infty$')
plt.show()
# Out:
# Iteration: 0, $\|\nabla L\|_\infty$ = 2.5000000292152436
# Iteration: 1, $\|\nabla L\|_\infty$ = 1.4025000145105992
# Iteration: 2, $\|\nabla L\|_\infty$ = 6.313685590316113
# Iteration: 3, $\|\nabla L\|_\infty$ = 2.218225112183192
# Iteration: 4, $\|\nabla L\|_\infty$ = 2.017926209123697
# Iteration: 5, $\|\nabla L\|_\infty$ = 1.917617234354427
# Iteration: 6, $\|\nabla L\|_\infty$ = 1.8434067247334682
# Iteration: 7, $\|\nabla L\|_\infty$ = 1.7693236813693678
# Iteration: 8, $\|\nabla L\|_\infty$ = 1.6932323019999926
# Iteration: 9, $\|\nabla L\|_\infty$ = 1.5631302560730695
# Iteration: 10, $\|\nabla L\|_\infty$ = 1.4389493706484253
# Iteration: 11, $\|\nabla L\|_\infty$ = 1.322947401767171
# Iteration: 12, $\|\nabla L\|_\infty$ = 1.1455305174177772
# Iteration: 13, $\|\nabla L\|_\infty$ = 0.9822325124131078
# Iteration: 14, $\|\nabla L\|_\infty$ = 0.7612263357066263
# Iteration: 15, $\|\nabla L\|_\infty$ = 0.4687960946955597
# Iteration: 16, $\|\nabla L\|_\infty$ = 0.04896541169200486
# Iteration: 17, $\|\nabla L\|_\infty$ = 0.007239175258212827
# Iteration: 18, $\|\nabla L\|_\infty$ = 5.293052080301841e-06

# %% [markdown]
# ### Exercise 3: Constrained Gauss-Newton
# We now consider a constrained version of the problem in Exercise 1, and we solve it by integrating Gauss-Newton and Newton-Lagrange methods:
# \begin{equation} \tag{3.1}
# 	\min_{x\in\R^n}~f(x)
# \quad\text{subject to}\quad
# 	h(x) = 0.
# \end{equation}
# Again, we handle the constraints by introducing the Lagrange multipliers $\lambda$ and the Lagrange function
# $$
# 	L(x,\lambda) = \tfrac 12\|F(x)\|_2^2 + \lambda^{\top}h(x)
# $$
# and use a linear approximation of $F$ and $h$ around $x_k$.
# Differently from what we did in Exercise 2, we only linearize the part in $x$:
# $$
# 	L(x_k+\Delta x,\lambda)
# {}\approx{}
# 	\tfrac 12F_k^{\top}F_k + F_k^{\top}J_k\Delta x + \tfrac 12\Delta x^{\top}J_k^{\top}J_k\Delta x + \lambda^{\top}(h_k + Jh_k \Delta x)
# $$
# where
# $$
# 	h_k\coloneqq h(x_k)
# \quad\text{and}\quad
# 	J_k\coloneqq JF{x_k}.
# $$
# The *linearized* problem (linearized around $x_k$) therefore is
# \begin{equation} \tag{3.2}
# 	\min_x~\tfrac 12\|F_k + J_k\Delta x\|_2^2
# \quad\text{subject to}\quad
# 	h_k + Jh_k\Delta x = 0.
# \end{equation}
# The optimality conditions of (3.2) are
# $$
# 	J_k^{\top} J_k \Delta x + J_k^{\top}F_k + Jh_k^{\top} \lambda = 0
# \quad\text{and}\quad
# 	h_k + Jh_k \Delta x = 0,
# $$
# which can be written in compact form as
# \begin{equation}\tag{3.3}
# 	\left[
# 		\begin{array}{cc}
# 			J_k^{\top} J_k & Jh_k^{\top} \\
# 			Jh_k & 0
# 		\end{array}
# 	\right]
# 	\left(
# 		\begin{array}{cc}
# 			\Delta x \\ \lambda
# 		\end{array}
# 	\right)
# {}={}
# 	\left(
# 		\begin{array}{cc}
# 			- J_k^{\top}F_k \\ -h_k
# 		\end{array}
# 	\right).
# \end{equation}
# By solving (3.3) we obtain $\Delta x$ and $\lambda$.
# Once again we use $d_k=\Delta x$ as our search direction and perform a line search to obtain $x_{k+1} = x_k + \alpha_k\,d_k$.
# The step length $\alpha_k$ can be computed by employing the same Armijo condition as before, namely
# \begin{equation} \tag{3.4}
# 	\varphi(x_k + \alpha_k d_k) {}\leq{} \varphi(x_k) + \sigma \alpha_k \varphi'(x_k;d_k)
# \end{equation}
# where $\phi(x)$ is the merit function defined by
# \begin{equation} \tag{3.5}
# 	\varphi(x) {}\coloneqq{} f(x) + c \|h(x)\|_1
# \end{equation}
# whose directional derivative is
# \begin{equation} \tag{3.6}
# 	\varphi'(x_k;d_k) {}={}	\nabla F_k^{\top}d_k - c \|h_k\|_1.
# \end{equation}
# Though methods have been developed to adapt $c$ at each iteration, you might start by fixing the value to  $c=100$.

# %%
# We redefine merit_fun to accept Ffun, rather than ffun
def merit_fun(Ffun, hfun, c, x):
    """
    Evaluates the merit function (3.5), given the nonlinear function Ffun

    Input arguments:
    - Ffun: vector-valued function
    - hfun: vector-valued function 
    - c: penalty parameter, strictly positive
    - x: the current iterate

    Returns:
    - the merit function (2.4) evaluated at x
    """
    F = Ffun(x)
    h = hfun(x)
    return 0.5 * (F.T @ F) + c * np.linalg.norm(h, ord = 1)

# %% [markdown]
# **Task 3a**: Implement a Constrained Gauss-Newton minimizer by completing the function *minimize_cgn*.
# This minimizer takes in the functions $F(x)$, $h(x)$ and an initial guess $x_0$.
# Remember that the provided *line_search* function has a slightly different prototype than last time (to account for the merit function).
#
# Use the stopping criterion:
# $$
#     \left\|
#         \begin{array}{c}
#             \nabla_xL(x_k, \lambda_k) \\ \nabla_\lambda L(x_k, \lambda_k)
#         \end{array}
#     \right\|_\infty
# {}={}
#     \left\|
#         \begin{array}{c}
#             \nabla f_k + Jh_k^{\top} \lambda_k \\ h_k
#         \end{array}
#     \right\|_\infty
# {}<{}
#     10^{-4}.
# $$

# %%
def minimize_cgn(Ffun, hfun, x0):
    """
    minimizes the problem (3.1) using a constrained Gauss-Newton method

    Input arguments:
    - Ffun: the function F, vector-valued
    - hfun: the function h, vector-valued
    - x0: the initial iterate

    Returns:
    - x: Final iterate
    - x_iters: Log of the iterates
    - x_grads: Log of the gradient norms
    """
    
    # Convergence tolerance
    grad_tol = 1e-4
    max_iters = 600

    # Check that x0 is a column vector
    assert x0.ndim == 1, "x0 must be an array"

    # Make sure Ffun returns an array
    F0 = Ffun(x0)
    assert F0.ndim == 1, "Ffun must return an array"

    # Make sure that hfun returns a column vector
    h0 = hfun(x0)
    assert h0.ndim == 1, "hfun must return an array"

    # Iteration logs
    x_iters = np.zeros((len(x0), max_iters))
    f_iters = np.zeros(max_iters)

    # Initialization
    x = np.copy(x0)
    lmbd = np.zeros_like(h0)

    for k in range(max_iters):
        # Check for divergence
        if np.max(np.abs(x)) > 1e6:
            raise AssertionError(f'minimize_cgn has diverged, np.max(np.abs(x)) = {np.max(np.abs(x))}')

        # Evaluate F and its Jacobian J
        F, J = finite_difference_jacob(Ffun, x)
        # Evaluate h and its Jacobian J_h
        h, J_h = finite_difference_jacob(hfun, x)
        
        # Update iteration log
        norm_grad_L = np.linalg.norm(
            np.concatenate([
                J.T @ F + J_h.T @ lmbd, 
                h
            ]),
            ord = np.inf
        )
        x_iters[:, k] = np.copy(x)
        f_iters[k] = norm_grad_L
        display(Latex(rf'Iteration: {k}, $\|\nabla L\|_\infty$ = {norm_grad_L}'))

        # Check for convergence
        if norm_grad_L < grad_tol:
            return x, x_iters[:, 0:k+1], f_iters[0:k+1]
        
        ###################### FILL THIS PART IN ####################
        # Find the search direction and lmbd
        nJ_h = np.shape(J_h)[0]
        M = np.block([[J.T @ J, J_h.T], [J_h, np.zeros((nJ_h, nJ_h))]])
        sol = np.linalg.solve(M, np.concatenate([-J.T @ F, -h]))

        # Now sol is the vector [Delta_x; lmbd]
        dk = sol[0:len(x)]
        lmbd = sol[len(x) :]

        # Line search
        f_grad = J.T @ F # Gradient of objective f = 0.5 * F.T @ F
        sigma = 0.01
        beta = 0.6
        c = 100
        x, _ = line_search(lambda y : merit_fun(Ffun, hfun, c, y), x, np.dot(f_grad, dk) - c * np.linalg.norm(h, ord = 1), dk, sigma, beta)

        #############################################################

    raise(AssertionError(f'minimize_cgn has diverged, maximum number of iterations attained.'))

# %% [markdown]
# **Task 3b**: Again, solve the problem
# $$
#     \min_{x,y}~\tfrac 12\left( x^2 + \left(\frac y2\right)^2 \right)
# \quad\text{s.t.}\quad
#     y = (x-1)^2 - x + 3
# $$
# by completing the code below.
#
# Play with the initial guess $x_0$ and see how the convergence is affected.

# %%
def Ffun(xy):
    """
    Evaluates the vector-valued function F

    Input arguments:
    - xy: the vector [x, y]
    
    Returns: F evaluated at xy (= an array)
    """
    x = xy[0]
    y = xy[1]
    ###################### FILL THIS PART IN ####################
    F = np.array([x, y / 2])
    #############################################################
    return F

def hfun(xy):
    """
    Evaluates the vector-valued function h

    Input arguments:
    - xy: the vector [x, y]

    Returns: h evaluated at xy (=an array)
    """
    x = xy[0]
    y = xy[1]
    ###################### FILL THIS PART IN ####################
    h = np.array([np.square(x - 1.) - x + 3. - y])
    #############################################################
    return h

# %%
# Create figure handle, plot objective and constraint
fig4 = plt.figure()
X, Y = np.meshgrid(
    np.linspace(-1., 4., 40),
    np.linspace(-3., 4., 40)
)
obj = np.copy(X)
for i in range(np.shape(X)[0]):
    for j in range(np.shape(X)[1]):
        F = Ffun([X[i, j], Y[i, j]])
        obj[i, j] = 0.5 * (F.T @ F)

c = plt.contour(X, Y, obj, 40)
t = np.linspace(-1., 4, 400)
plt.plot(t, 3. + np.square(t - 1.) - t, 'k', label = 'Constraint')
plt.xlim([-1., 4.])
plt.ylim([-3., 4.])

# Call the Constrained Gauss-Newton method
x0 = np.array([3., 1.])
x0 = np.array([2.5, 3.])
x0 = np.array([3., 2.])
_, x, grad_iters = minimize_cgn(lambda x : Ffun(x), lambda x: hfun(x), x0)

# Plot solution
plt.plot(x[0, :], x[1, :], 'ro-', label="Iterates")
plt.xlabel('x')
plt.ylabel('y')
plt.title('Solution to the constrained optimization problem')
plt.legend()
plt.show()

# Plot gradient norms
fig5 = plt.figure()
plt.semilogy(grad_iters, '.')
plt.grid(True)
plt.title('Gradient norm at each iteration')
plt.xlabel('iterations')
plt.ylabel(r'$\|\nabla L(x_k, \lambda_k\|_\infty$')
plt.show()
# Out:
# Iteration: 0, $\|\nabla L\|_\infty$ = 2.999999981767587
# Iteration: 1, $\|\nabla L\|_\infty$ = 1.7217136104606796
# Iteration: 2, $\|\nabla L\|_\infty$ = 1.6087910605491027
# Iteration: 3, $\|\nabla L\|_\infty$ = 1.4069778484184745
# Iteration: 4, $\|\nabla L\|_\infty$ = 0.5038730650130435
# Iteration: 5, $\|\nabla L\|_\infty$ = 0.3188940828967567
# Iteration: 6, $\|\nabla L\|_\infty$ = 0.2517080151292729
# Iteration: 7, $\|\nabla L\|_\infty$ = 0.17491272979156613
# Iteration: 8, $\|\nabla L\|_\infty$ = 0.13625422361406536
# Iteration: 9, $\|\nabla L\|_\infty$ = 0.0983185559894415
# Iteration: 10, $\|\nabla L\|_\infty$ = 0.07549770120305488
# Iteration: 11, $\|\nabla L\|_\infty$ = 0.05547797130448151
# Iteration: 12, $\|\nabla L\|_\infty$ = 0.042196120348386934
# Iteration: 13, $\|\nabla L\|_\infty$ = 0.031300567883547736
# Iteration: 14, $\|\nabla L\|_\infty$ = 0.02366925991351465
# Iteration: 15, $\|\nabla L\|_\infty$ = 0.017646619970369093
# Iteration: 16, $\|\nabla L\|_\infty$ = 0.013298970717009806
# Iteration: 17, $\|\nabla L\|_\infty$ = 0.009942603374211711
# Iteration: 18, $\|\nabla L\|_\infty$ = 0.007478433389066952
# Iteration: 19, $\|\nabla L\|_\infty$ = 0.005599628786365329
# Iteration: 20, $\|\nabla L\|_\infty$ = 0.004207106494366508
# Iteration: 21, $\|\nabla L\|_\infty$ = 0.003152843000583494
# Iteration: 22, $\|\nabla L\|_\infty$ = 0.0023672944772434867
# Iteration: 23, $\|\nabla L\|_\infty$ = 0.0017749409425739104
# Iteration: 24, $\|\nabla L\|_\infty$ = 0.0013322282455289214
# Iteration: 25, $\|\nabla L\|_\infty$ = 0.0009991379095319886
# Iteration: 26, $\|\nabla L\|_\infty$ = 0.0007497922476070729
# Iteration: 27, $\|\nabla L\|_\infty$ = 0.0005624234128278616
# Iteration: 28, $\|\nabla L\|_\infty$ = 0.0004220168873418917
# Iteration: 29, $\|\nabla L\|_\infty$ = 0.00031657527279371767
# Iteration: 30, $\|\nabla L\|_\infty$ = 0.00023755034228722938
# Iteration: 31, $\|\nabla L\|_\infty$ = 0.00017821367162873525
# Iteration: 32, $\|\nabla L\|_\infty$ = 0.0001337139268076104
# Iteration: 33, $\|\nabla L\|_\infty$ = 0.00010032975346563333
# Iteration: 34, $\|\nabla L\|_\infty$ = 7.526920292355577e-05
